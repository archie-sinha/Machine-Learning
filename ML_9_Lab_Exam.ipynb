# %% [markdown]
# <a href="https://colab.research.google.com/github/archie-sinha/Machine-Learning/blob/main/ML_9_Lab_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Lab Exam

# %% [markdown]
# #**Archisha Sinha**
# ##Course: Machine Learning
# ##Title: PRACTICE

# %% [markdown]
# ##TASKS:

# %% [markdown]
# 1. Import lib
# 2. Read the DS
# 3. plot one scatter plot (one feature) and write inference
# 4. import sk learn lib for LR
# 5. do TTS at 70, 30
# 5. B0, B1 display
# 6. Use Lib to display R2 score
# 7. Use proper code comments and inferences

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("Real estate.csv") #Reading the csv file

# %%
df.size #performing EDA
# Out:
# 3312

# %%
df.shape
# Out:
# (414, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
df.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
df.head(5)
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
x=df["X2 house age"]
y=df["Y house price of unit area"]

# %%
plt.figure(figsize=(7,4))
plt.scatter(x,y, color="purple")
plt.xlabel("House Age")
plt.ylabel("House Price")
# Out:
# Text(0, 0.5, 'House Price')

# %%
X= df.drop(["Y house price of unit area", "X5 latitude", "X6 longitude" ],axis=1)
y= df["Y house price of unit area"]

# %%
sns.pairplot(df, diag_kind="hist") #Finding Dependent and Independent Variables

# %% [markdown]
# Dep Var: Y: House Price
#
# X3 distance to the nearest MRT station VS House Price: Negative Association
#
# X4 number of convenience stores VS House Price:  Positive association

# %%
DV= df["Y house price of unit area"]
IV1=df["X3 distance to the nearest MRT station"]
IV2=df["X4 number of convenience stores"]

# %%
plt.scatter(IV1, DV)
plt.xlabel("X3 distance to the nearest MRT station")
plt.ylabel("Y house price of unit area")
# Out:
# Text(0, 0.5, 'Y house price of unit area')

# %%
plt.scatter(IV2, DV)
plt.xlabel("X4 number of convenience stores")
plt.ylabel("Y house price of unit area")
# Out:
# Text(0, 0.5, 'Y house price of unit area')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
X=df.drop(["Y house price of unit area","X1 transaction date", "X2 house age", "X5 latitude", "X6 longitude"], axis=1)
Y= df["Y house price of unit area"].values.reshape(-1,1)

# %%
#Train and test Split
X_train,X_test,y_train, y_test= train_test_split(X,Y, test_size=0.3, random_state=45)

# %%
reg= LinearRegression().fit(X,Y)

# %%
reg.score
# Out:
# <bound method RegressorMixin.score of LinearRegression()>

# %%
reg.intercept_
#B0=39.9187682
# Out:
# array([39.9187682])

# %%
reg.coef_
#B1=-0.00367817
#B2= -0.00558963
#B3= 1.19270181
# Out:
# array([[-0.00367817, -0.00558963,  1.19270181]])

# %%
prediction= reg.predict(X_test)

# %%
r2_score(y_test, prediction)
#R2 score= 0.4547790561173889
# Out:
# 0.4547790561173889
