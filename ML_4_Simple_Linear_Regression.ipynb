# %% [markdown]
# #**Archisha Sinha**
# ##Course: Machine Learning
# ##Title: Simple Linear Regression

# %% [markdown]
# **Linear Regression**
#
# The mathematical approach to find the relationship between two or more variables is known as Regression in AI. Regression is widely used in Machine Learning to predict the behavior of one variable depending upon the value of another variable.
#
# Linear regression is used for finding linear relationship between target and one or more predictors. Linear regression is a linear model, e.g. a model that assumes a linear relationship between the input variables (x) and the single output variable (y).
#
# More specifically, that ycan be calculated from a linear combination of the input variables (x).   There are two types of linear regression- Simple and Multiple. When there is a single input variable (x), the method is referred to as simple linear regression. When there are multiple input variables, refers to the method as multiple linear regression.
#
# One additional coefficient is also added, giving the line an additional degree of freedom (e.g. moving up and down on a two-dimensional plot) and is often called the intercept or the bias
# coefficient.
#
# For example, in a simple regression problem (a single x and a single y), the form of the model
# would be:
#
#  **y = b 0 + b 1 *x**
#
# In higher dimensions when we have more than one input (x), the line is called a plane or a hyper-plane. The representation therefore is the form of the equation and the specific values used for the coefficients (e.g. b 0 and b 1 in the above example).
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Task 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Importing necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = np.array([17, 21, 24, 28, 14, 16, 19, 22, 15, 18])
y= np.array([140, 189, 210, 240, 130, 100, 135, 166, 130, 170])
print(x)
print(y)
# Out:
# [17 21 24 28 14 16 19 22 15 18]
# [140 189 210 240 130 100 135 166 130 170]

# %% [markdown]
# #Plot a scatter plot for bmi and cholestrol
#
# Give the inference

# %%
plt.scatter(x,y,c="purple")
plt.xlabel("X")
plt.ylabel("Y")
plt.savefig("Fig1.png")

#Positive association

# %% [markdown]
# Write a function for linear regression

# %%
mean_x=0
mean_y=0
y_hat=0
B1=0
B0=0

# %%
plt.scatter(x,y)

# %%
def linear_regression(x, y):
  mean_x= sum(x)/ len(x)
  mean_y= sum(y)/ len(y)
  #a= x-x'
  #b= y-y'
  a=x-mean_x
  #print(a)
  b=y-mean_y
  #print(b)
  c= a**2
  #print(c)
  d= a*b
  #print(d)
  B1= sum(d)/sum(c)
  B0= mean_y- (B1*mean_x)
  return(B1,B0)

# %%
linear_regression(x,y)
# Out:
# (8.828306264501157, -10.269141531322418)

# %%
def prediction_linear_regression(num):
    B1,B0=linear_regression(x,y)
    y_hat= B0+ B1*num
    #print(y_hat)
    return(y_hat)

# %%
prediction_linear_regression(27)
# Out:
# 228.0951276102088

# %%
plt.plot(x,(B0+B1*x))

# %% [markdown]
# #Coefficient of Regression (R^2)
# Without using SK Learn

# %%
mean_y=sum(y)/len(y)
SST =sum((y-mean_y)**2)
print(SST)
# Out:
# 16292.0

# %%
y_hat=[prediction_linear_regression(j) for j in x]

# %%
SSE= sum((y-y_hat)**2)
print(SSE)
# Out:
# 2855.317865429236

# %%
def R_square(SSE,SST):
  #R_sq= 1- (sum((y-y_hat)**2)/sum((y-mean_y)**2))
  R_sq= 1- SSE/SST

  print(R_sq)

# %%
R_square(SSE,SST)
# Out:
# 0.8247411081862732

# %% [markdown]
# ##Task 2

# %% [markdown]
# With using SK Learn

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
x = np.array([17, 21, 24, 28, 14, 16, 19, 22, 15, 18]).reshape(-1,1)
y= np.array([140, 189, 210, 240, 130, 100, 135, 166, 130, 170]).reshape(-1,1)
reg= LinearRegression().fit(x,y)   #.fit() is the fn for B1 and B0
reg.score(x,y)
# Out:
# 0.8247411081862734
